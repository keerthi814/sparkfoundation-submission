# %% [markdown]
# # Keerthi Sri Geddada

# %%
import pandas as pd
df=pd.read_csv('SampleSuperstore.csv')
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.isnull().any()
# Out:
# Ship Mode       False
# Segment         False
# Country         False
# City            False
# State           False
# Postal Code     False
# Region          False
# Category        False
# Sub-Category    False
# Sales           False
# Quantity        False
# Discount        False
# Profit          False
# dtype: bool

# %% [markdown]
# # There is no null values in the dataset

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
t=df.describe().transpose()
t
# Out:
#               count          mean           std       min          25%  \
# Postal Code  9994.0  55190.379428  32063.693350  1040.000  23223.00000
# Sales        9994.0    229.858001    623.245101     0.444     17.28000
# Quantity     9994.0      3.789574      2.225110     1.000      2.00000
# Discount     9994.0      0.156203      0.206452     0.000      0.00000
# Profit       9994.0     28.656896    234.260108 -6599.978      1.72875
#
#                     50%        75%        max
# Postal Code  56430.5000  90008.000  99301.000
# Sales           54.4900    209.940  22638.480
# Quantity         3.0000      5.000     14.000
# Discount         0.2000      0.200      0.800
# Profit           8.6665     29.364   8399.976

# %% [markdown]
# ## From above the maximum quantity ordered by customers is 14 , maximum discount is 0.8 , maximum profit is 8399.976 and maximum sales are 22638.480

# %%
t =df['State'].value_counts().rename_axis('State').reset_index(name='number of orders')
t
# Out:
#                    State  number of orders
# 0             California              2001
# 1               New York              1128
# 2                  Texas               985
# 3           Pennsylvania               587
# 4             Washington               506
# 5               Illinois               492
# 6                   Ohio               469
# 7                Florida               383
# 8               Michigan               255
# 9         North Carolina               249
# 10               Arizona               224
# 11              Virginia               224
# 12               Georgia               184
# 13             Tennessee               183
# 14              Colorado               182
# 15               Indiana               149
# 16              Kentucky               139
# 17         Massachusetts               135
# 18            New Jersey               130
# 19                Oregon               124
# 20             Wisconsin               110
# ...

# %%
t =df['City'].value_counts().rename_axis('City').reset_index(name='number of orders')
t
# Out:
#               City  number of orders
# 0    New York City               915
# 1      Los Angeles               747
# 2     Philadelphia               537
# 3    San Francisco               510
# 4          Seattle               428
# ..             ...               ...
# 526      Pensacola                 1
# 527    Chapel Hill                 1
# 528        Abilene                 1
# 529       Palatine                 1
# 530        Margate                 1
#
# [531 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
t.plot(kind="line")
plt.title('orders based on city') 
plt.ylabel('count') 
plt.xlabel('city') 

plt.show()

# %%
t.plot(kind='hist', figsize=(10, 6))
plt.title('orders based on city') 
plt.ylabel('count') 
plt.xlabel('city') 

plt.show()

# %%
t=df.groupby(["State", "City"]).size().reset_index(name="count")
t
# Out:
#          State        City  count
# 0      Alabama      Auburn      6
# 1      Alabama     Decatur     13
# 2      Alabama    Florence      5
# 3      Alabama      Hoover      4
# 4      Alabama  Huntsville     10
# ..         ...         ...    ...
# 599  Wisconsin    Superior      9
# 600  Wisconsin    Waukesha      1
# 601  Wisconsin      Wausau      4
# 602  Wisconsin  West Allis      2
# 603    Wyoming    Cheyenne      1
#
# [604 rows x 3 columns]

# %%
import matplotlib.pyplot as pit
t.plot(kind="line")
plt.title('orders based on state and city') 
plt.ylabel('count') 
plt.xlabel('state and city') 

plt.show()

# %%
t.plot(kind='hist', figsize=(10, 6))
plt.title('orders based on state and city') 
plt.ylabel('count') 
plt.xlabel('state and city') 

plt.show()

# %%
t[t['count']==t['count'].max()]
# Out:
#         State           City  count
# 389  New York  New York City    915

# %% [markdown]
# # From New York city there are maximum orders

# %%
t[t['count']==t['count'].min()]
# Out:
#           State            City  count
# 21     Arkansas          Conway      1
# 27     Arkansas          Rogers      1
# 28     Arkansas      Springdale      1
# 31   California         Antioch      1
# 39   California  Citrus Heights      1
# ..          ...             ...    ...
# 549        Utah          Layton      1
# 572  Washington          Auburn      1
# 578  Washington         Everett      1
# 600   Wisconsin        Waukesha      1
# 603     Wyoming        Cheyenne      1
#
# [78 rows x 3 columns]

# %% [markdown]
# # There are 78 cities where orders less and we have to increase it.

# %%
t=df.groupby(["Category", "Sub-Category"]).size().reset_index(name="count")
t
# Out:
#            Category Sub-Category  count
# 0         Furniture    Bookcases    228
# 1         Furniture       Chairs    617
# 2         Furniture  Furnishings    957
# 3         Furniture       Tables    319
# 4   Office Supplies   Appliances    466
# 5   Office Supplies          Art    796
# 6   Office Supplies      Binders   1523
# 7   Office Supplies    Envelopes    254
# 8   Office Supplies    Fasteners    217
# 9   Office Supplies       Labels    364
# 10  Office Supplies        Paper   1370
# 11  Office Supplies      Storage    846
# 12  Office Supplies     Supplies    190
# 13       Technology  Accessories    775
# 14       Technology      Copiers     68
# 15       Technology     Machines    115
# 16       Technology       Phones    889

# %% [markdown]
# ## There are more items in Office Supplies Category we have to add more items in both Furniture and Technology categories to increase our sales

# %%
import matplotlib.pyplot as plt
t.plot(kind="line")
plt.title('orders based on category') 
plt.ylabel('count') 
plt.xlabel('Category') 

plt.show()

# %%
t.plot(kind='hist', figsize=(10, 6))
plt.title('orders based on category') 
plt.ylabel('count') 
plt.xlabel('Category')

plt.show()

# %%
t.plot(kind='bar', figsize=(8, 5))
plt.title('orders based on category')
plt.ylabel('count') 
plt.xlabel('Category') 

plt.show()

# %%
t=df.groupby(["City", "State","Region"]).size().reset_index(name="count")
t
# Out:
#             City         State   Region  count
# 0       Aberdeen  South Dakota  Central      1
# 1        Abilene         Texas  Central      1
# 2          Akron          Ohio     East     21
# 3    Albuquerque    New Mexico     West     14
# 4     Alexandria      Virginia    South     16
# ..           ...           ...      ...    ...
# 599   Woonsocket  Rhode Island     East      4
# 600      Yonkers      New York     East     15
# 601         York  Pennsylvania     East      5
# 602      Yucaipa    California     West      1
# 603         Yuma       Arizona     West      4
#
# [604 rows x 4 columns]

# %%
df["Region"].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Region'>

# %% [markdown]
# ## From  south region the orders are less so we should concentrate on south region

# %%
df['Category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
df['Sub-Category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %%
df1=df[['Category','Sub-Category','Sales','Quantity','Discount','Profit']]
df1
# Out:
#              Category Sub-Category     Sales  Quantity  Discount    Profit
# 0           Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1           Furniture       Chairs  731.9400         3      0.00  219.5820
# 2     Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3           Furniture       Tables  957.5775         5      0.45 -383.0310
# 4     Office Supplies      Storage   22.3680         2      0.20    2.5164
# ...               ...          ...       ...       ...       ...       ...
# 9989        Furniture  Furnishings   25.2480         3      0.20    4.1028
# 9990        Furniture  Furnishings   91.9600         2      0.00   15.6332
# 9991       Technology       Phones  258.5760         2      0.20   19.3932
# 9992  Office Supplies        Paper   29.6000         4      0.00   13.3200
# 9993  Office Supplies   Appliances  243.1600         2      0.00   72.9480
#
# [9994 rows x 6 columns]

# %%
df1[['Sales','Profit']].plot(kind='line', figsize=(10, 6))

plt.title('sales and profit')

plt.show()

# %%
df1[['Sales','Profit']].plot(kind='hist', figsize=(10, 6))

plt.title('sales and profit')

plt.show()

# %%
df1.plot(x="Quantity",y="Discount")

plt.show()

# %%
df1[['Quantity','Discount']].plot(kind='hist', figsize=(10, 6))

plt.title('quantity and Discount')

plt.show()

# %%
df1[['Discount','Profit']].plot(kind='hist', figsize=(10, 6))

plt.title('quantity and Discount')

plt.show()

# %%
df1=df[['Sub-Category','Quantity','Discount','Profit']]
df1
# Out:
#      Sub-Category  Quantity  Discount    Profit
# 0       Bookcases         2      0.00   41.9136
# 1          Chairs         3      0.00  219.5820
# 2          Labels         2      0.00    6.8714
# 3          Tables         5      0.45 -383.0310
# 4         Storage         2      0.20    2.5164
# ...           ...       ...       ...       ...
# 9989  Furnishings         3      0.20    4.1028
# 9990  Furnishings         2      0.00   15.6332
# 9991       Phones         2      0.20   19.3932
# 9992        Paper         4      0.00   13.3200
# 9993   Appliances         2      0.00   72.9480
#
# [9994 rows x 4 columns]

# %%
df1[df1['Quantity']==df1['Quantity'].max()]
# Out:
#      Sub-Category  Quantity  Discount    Profit
# 113     Fasteners        14       0.2   14.5348
# 139   Furnishings        14       0.0   20.6976
# 575         Paper        14       0.0   78.7528
# 660       Storage        14       0.2 -135.7650
# 1045       Chairs        14       0.3  -18.1860
# 1363      Binders        14       0.7  -25.5920
# 1429       Labels        14       0.0  196.6132
# 1433       Chairs        14       0.0  163.7874
# 1711   Appliances        14       0.0  510.6360
# 2793       Phones        14       0.2   94.0702
# 2947      Binders        14       0.2   22.7360
# 3441        Paper        14       0.0   49.0140
# 3902      Storage        14       0.0   75.6952
# 5385       Phones        14       0.4   72.7888
# 5646  Furnishings        14       0.0   69.1992
# 5668      Binders        14       0.2   17.5448
# 6131       Chairs        14       0.1  161.9674
# 6488        Paper        14       0.2   96.0232
# 6499  Accessories        14       0.0   64.3678
# ...

# %% [markdown]
# ## when the quantity is high the discount can be more so the sales will increase
# ## 3 or 4 items which people need combinedly can be sell for low price so the sales will increase
